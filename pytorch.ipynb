# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulBarakoti-programming/BlockChainAgreements/blob/master/pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1510789129.py in <cell line: 0>()
# ----> 1 python.__version__
#
# NameError: name 'python' is not defined
